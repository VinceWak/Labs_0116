# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/vincentwakim/Documents/DAFT_0116/module_2/Project_Week_4/Group 4 Elon_s Tweets/ElonTweets(Sentiment) 10-28-22.csv")

print(df.isnull().sum())

print(df.duplicated().sum())

print(df.dtypes)

print(df.describe())
df
# Out:
# Unnamed: 0.2            0
# Unnamed: 0.1            0
# Unnamed: 0              0
# Datetime                0
# Tweet Id                0
# Text                    0
# Username                0
# location                0
# reply count             0
# retweet count           0
# like count              0
# language                0
# Twitter Access Point    0
# Follower Count          0
#  Friends Count          0
# verified                0
# Date                    0
# mentions                0
# sentiment               0
# dtype: int64
# 0
# Unnamed: 0.2             int64
# Unnamed: 0.1             int64
# Unnamed: 0               int64
# Datetime                object
# Tweet Id                 int64
# Text                    object
# Username                object
# location                object
# reply count              int64
# retweet count            int64
# like count               int64
# language                object
# Twitter Access Point    object
# ...

# %%
df.dropna(inplace=True)

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df['Tweet Id'] = imputer.fit_transform(df[['Tweet Id']])

df['Tweet Id'] = df['Tweet Id'].astype('int')

df.drop_duplicates(inplace=True)
df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                 0             0           0  2022-10-28 03:49:11+00:00
# 1                 1             1           1  2022-10-28 01:50:49+00:00
# 2                 2             2           2  2022-10-27 21:45:47+00:00
# 3                 3             3           3  2022-10-27 16:17:39+00:00
# 4                 4             4           4  2022-10-27 13:19:25+00:00
# ...             ...           ...         ...                        ...
# 17440         17440         17440       17440  2011-12-03 08:22:07+00:00
# 17441         17441         17441       17441  2011-12-03 08:20:28+00:00
# 17442         17442         17442       17442  2011-12-01 10:29:04+00:00
# 17443         17443         17443       17443  2011-12-01 09:55:11+00:00
# 17444         17444         17444       17444  2010-06-04 18:31:57+00:00
#
#                   Tweet Id                                               Text  \
# ...
